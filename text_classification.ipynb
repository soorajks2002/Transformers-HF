# %%
! pip install transformers -q

# %%
from transformers import pipeline

# %% [markdown]
# # Pipeline

# %%
pipe = pipeline("text-classification", model="ProsusAI/finbert")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/758 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/252 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.

# %%
pipe("hello world")
# Out:
# [{'label': 'neutral', 'score': 0.8508199453353882}]

# %%
pipe(["hello world", "bad world", "good world"])
# Out:
# [{'label': 'neutral', 'score': 0.8508199453353882},
#  {'label': 'negative', 'score': 0.7866925597190857},
#  {'label': 'neutral', 'score': 0.5553379654884338}]

# %% [markdown]
# # Tokenizer & Model

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# %%
tokenizer = AutoTokenizer.from_pretrained("ProsusAI/finbert")
model = AutoModelForSequenceClassification.from_pretrained("ProsusAI/finbert")

# %%
new_pipe = pipeline(task='text-classification', model=model, tokenizer=tokenizer)

# %%
new_pipe("hello world")
# Out:
# [{'label': 'neutral', 'score': 0.8508199453353882}]

# %%
new_pipe(["hello world", "bad world", "good world"])
# Out:
# [{'label': 'neutral', 'score': 0.8508199453353882},
#  {'label': 'negative', 'score': 0.7866925597190857},
#  {'label': 'neutral', 'score': 0.5553379654884338}]
