# %%
! pip install transformers -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 16.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 11.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 35.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 43.6 MB/s eta 0:00:00

# %%
from transformers import pipeline,set_seed

# %%
pipe = pipeline("text-generation", model="gpt2")
# Out:
# ...
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.

# %%
set_seed(24)

# %%
pipe("this is an AI named sevak", max_length=50, num_return_sequences=2)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "this is an AI named sevak, he has a lot of features and he has a name and kind of kind of wants me to learn his stuff, but at the same time he's talking about other things and things like, 'What kind"},
#  {'generated_text': 'this is an AI named sevak, it\'s called that because it takes the user as the agent instead of giving an AI the responsibility to find it. It is more often called a "tasker" or a "game model" because they'}]
